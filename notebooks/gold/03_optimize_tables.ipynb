# %%
spark.sql("OPTIMIZE workspace.gold.customer_sales")
spark.sql("OPTIMIZE workspace.gold.product_performance")
spark.sql("OPTIMIZE workspace.gold.daily_sales")
spark.sql("OPTIMIZE workspace.gold.category_sales")
spark.sql("OPTIMIZE workspace.gold.customer_activity")

# %%
# %sql
DESCRIBE DETAIL workspace.gold.customer_sales;

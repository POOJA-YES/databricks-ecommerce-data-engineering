# %%
DATA_PATH = "/Workspace/Users/aipooja.yes@gmail.com/databricks-ecommerce-data-engineering/data"

# %%
from pyspark.sql import functions as F

# Read customer source data
customers_df = (
    spark.read
    .option("header", "true")
    .option("inferSchema", "true")
     .csv(f"{DATA_PATH}/customers.csv")
)

# %%
customers_df.show()
# Out:
# +-----------+----------+---------+--------------------+---------+-----+-------+-----------+----------------+----------------+
# |customer_id|first_name|last_name|               email|     city|state|country|signup_date|customer_segment|      updated_at|
# +-----------+----------+---------+--------------------+---------+-----+-------+-----------+----------------+----------------+
# |       C001|     Aarav|   Sharma|aarav.sharma@exam...|Bengaluru|   KA|  India| 2025-01-10|         Premium|20-08-2026 10:30|
# |       C002|     Priya|    Patel|priya.patel@examp...|   Mumbai|   MH|  India| 2025-02-15|         Regular|20-08-2026 11:10|
# |       C003|     Rahul|    Verma|rahul.verma@examp...|    Delhi|   DL|  India| 2025-03-05|         Premium|20-08-2026 12:00|
# |       C004|     Sneha|      Rao|sneha.rao@example...|Hyderabad|   TS|  India| 2025-04-12|         Regular|20-08-2026 13:15|
# |       C005|    Vikram|    Singh|vikram.singh@exam...|     Pune|   MH|  India| 2025-05-01|         Premium|20-08-2026 14:20|
# |       C006|    Ananya|     Iyer|ananya.iyer@examp...|  Chennai|   TN|  India| 2025-05-18|         Regular|21-08-2026 09:00|
# |       C007|     Karan|    Mehta|karan.mehta@examp...|Ahmedabad|   GJ|  India| 2025-06-10|         Regular|21-08-2026 09:45|
# |       C008|      Neha|   Kapoor|neha.kapoor@examp...|  Kolkata|   WB|  India| 2025-07-22|         Premium|21-08-2026 10:15|
# |       C009|     Rohan|    Gupta|rohan.gupta@examp...|   Jaipur|   RJ|  India| 2025-08-03|         Regular|21-08-2026 11:30|
# |       C010|     Meera|     Nair|meera.nair@exampl...|    Kochi|   KL|  India| 2025-09-14|         Premium|21-08-2026 12:10|
# +-----------+----------+---------+--------------------+---------+-----+-------+-----------+----------------+----------------+

# %%
customers_df.printSchema()
# Out:
# root
#  |-- customer_id: string (nullable = true)
#  |-- first_name: string (nullable = true)
#  |-- last_name: string (nullable = true)
#  |-- email: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- state: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- signup_date: date (nullable = true)
#  |-- customer_segment: string (nullable = true)
#  |-- updated_at: string (nullable = true)

# %%
customers_bronze = (
    customers_df
    .withColumn("_ingestion_timestamp", F.current_timestamp())
    .withColumn("_source_file", F.lit("customers.csv"))
)

# %%
customers_bronze.show()
# Out:
# +-----------+----------+---------+--------------------+---------+-----+-------+-----------+----------------+----------------+--------------------+-------------+
# |customer_id|first_name|last_name|               email|     city|state|country|signup_date|customer_segment|      updated_at|_ingestion_timestamp| _source_file|
# +-----------+----------+---------+--------------------+---------+-----+-------+-----------+----------------+----------------+--------------------+-------------+
# |       C001|     Aarav|   Sharma|aarav.sharma@exam...|Bengaluru|   KA|  India| 2025-01-10|         Premium|20-08-2026 10:30|2026-08-31 17:12:...|customers.csv|
# |       C002|     Priya|    Patel|priya.patel@examp...|   Mumbai|   MH|  India| 2025-02-15|         Regular|20-08-2026 11:10|2026-08-31 17:12:...|customers.csv|
# |       C003|     Rahul|    Verma|rahul.verma@examp...|    Delhi|   DL|  India| 2025-03-05|         Premium|20-08-2026 12:00|2026-08-31 17:12:...|customers.csv|
# |       C004|     Sneha|      Rao|sneha.rao@example...|Hyderabad|   TS|  India| 2025-04-12|         Regular|20-08-2026 13:15|2026-08-31 17:12:...|customers.csv|
# |       C005|    Vikram|    Singh|vikram.singh@exam...|     Pune|   MH|  India| 2025-05-01|         Premium|20-08-2026 14:20|2026-08-31 17:12:...|customers.csv|
# |       C006|    Ananya|     Iyer|ananya.iyer@examp...|  Chennai|   TN|  India| 2025-05-18|         Regular|21-08-2026 09:00|2026-08-31 17:12:...|customers.csv|

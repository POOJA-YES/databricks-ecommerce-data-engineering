# %%
DATA_PATH = "/Workspace/Users/aipooja.yes@gmail.com/databricks-ecommerce-data-engineering/data"

# %%
from pyspark.sql import functions as F
order_items_df = (
    spark.read
    .option("header", "true")
    .option("inferSchema", "true")
    .csv(f"{DATA_PATH}/order_items.csv")
)

order_items_bronze = (
    order_items_df
    .withColumn("_ingestion_timestamp", F.current_timestamp())
    .withColumn("_source_file", F.lit("order_items.csv"))
)

(
    order_items_bronze.write
    .format("delta")
    .mode("overwrite")
    .saveAsTable("workspace.bronze.order_items")
)

display(order_items_bronze)

# %%
# %sql
select *from workspace.bronze.order_items
